# %%
import numpy as np
import sys
import numpy as np
import pandas as pd
import matplotlib as mpl
import sklearn

# %%
df = pd.read_csv('NHIS_OPEN_GJ_2017_100.csv',engine = 'python')

# %%
df.describe()
# Out:
#             기준년도         가입자일련번호            성별코드     연령대코드(5세단위)  \
# count  1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean      2017.0   500000.500000        1.469590       10.527041
# std          0.0   288675.278933        0.499075        2.841183
# min       2017.0        1.000000        1.000000        5.000000
# 25%       2017.0   250000.750000        1.000000        8.000000
# 50%       2017.0   500000.500000        1.000000       10.000000
# 75%       2017.0   750000.250000        2.000000       13.000000
# max       2017.0  1000000.000000        2.000000       18.000000
#
#                  시도코드      신장(5Cm단위)       체중(5Kg단위)           허리둘레  \
# count  1000000.000000  1000000.00000  1000000.000000  999734.000000
# mean        33.694584      162.22823       63.268710      81.231603
# std         12.672969        9.28462       12.520732      11.837625
# min         11.000000      130.00000       25.000000       8.000000
# ...

# %%
df_sample = df[['성별코드', '연령대코드(5세단위)','수축기혈압','이완기혈압','식전혈당(공복혈당)','HDL콜레스테롤','혈색소','요단백','혈청크레아티닌','신장(5Cm단위)', '체중(5Kg단위)', '허리둘레', '흡연상태', '음주여부']]

# %%
df_sample.describe()
# Out:
#                  성별코드     연령대코드(5세단위)          수축기혈압          이완기혈압  \
# count  1000000.000000  1000000.000000  999981.000000  999982.000000
# mean         1.469590       10.527041     122.427552      76.048641
# std          0.499075        2.841183      14.558082       9.895772
# min          1.000000        5.000000      58.000000      30.000000
# 25%          1.000000        8.000000     112.000000      70.000000
# 50%          1.000000       10.000000     120.000000      76.000000
# 75%          2.000000       13.000000     131.000000      82.000000
# max          2.000000       18.000000     273.000000     185.000000
#
#           식전혈당(공복혈당)       HDL콜레스테롤            혈색소            요단백  \
# count  999958.000000  999956.000000  999948.000000  995408.000000
# mean      100.453168      56.938494      14.226105       1.094422
# std        24.251247      19.524964       1.587416       0.438166
# min        25.000000       1.000000       1.000000       1.000000
# ...

# %%
df['당뇨병'] = df_sample['식전혈당(공복혈당)'].apply(lambda x : x >= 126)

# %%
df['당뇨병'].value_counts()
# Out:
# False    922785
# True      77215
# Name: 당뇨병, dtype: int64

# %%
df.describe()
# Out:
#             기준년도         가입자일련번호            성별코드     연령대코드(5세단위)  \
# count  1000000.0  1000000.000000  1000000.000000  1000000.000000
# mean      2017.0   500000.500000        1.469590       10.527041
# std          0.0   288675.278933        0.499075        2.841183
# min       2017.0        1.000000        1.000000        5.000000
# 25%       2017.0   250000.750000        1.000000        8.000000
# 50%       2017.0   500000.500000        1.000000       10.000000
# 75%       2017.0   750000.250000        2.000000       13.000000
# max       2017.0  1000000.000000        2.000000       18.000000
#
#                  시도코드      신장(5Cm단위)       체중(5Kg단위)           허리둘레  \
# count  1000000.000000  1000000.00000  1000000.000000  999734.000000
# mean        33.694584      162.22823       63.268710      81.231603
# std         12.672969        9.28462       12.520732      11.837625
# min         11.000000      130.00000       25.000000       8.000000
# ...

# %%
df['당뇨병'].describe()
# Out:
# count     1000000
# unique          2
# top         False
# freq       922785
# Name: 당뇨병, dtype: object

# %%
yachol = df['음주여부'] == 1

# %%
nachol = df['음주여부'] != 1

# %%
df_achol = df.loc[yachol,:].copy()

# %%
df_noachol = df.loc[~yachol,:].copy()

# %%
df_noachol
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 1       2017        2     1            7    11        180         80  89.0
# 2       2017        3     1            9    41        165         75  91.0
# 3       2017        4     1           11    48        175         80  91.0
# 4       2017        5     1           11    30        165         60  80.0
# 6       2017        7     2           10    27        150         55  69.0
# ...      ...      ...   ...          ...   ...        ...        ...   ...
# 999991  2017   999992     2            8    41        165         70  81.0
# 999994  2017   999995     2           11    27        150         50  72.6
# 999995  2017   999996     1           10    48        175         80  92.1
# 999996  2017   999997     1            8    41        170         75  86.0
# 999998  2017   999999     1            6    29        175         60  72.0
#
# ...

# %%
yachol
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997     True
# 999998    False
# 999999     True
# Name: 음주여부, Length: 1000000, dtype: bool

# %%
df_achol_1 = df_achol[["음주여부","당뇨병"]]

# %%
df_achol_2 = df_noachol[["음주여부","당뇨병"]]

# %%
df_achol_1
# Out:
#         음주여부    당뇨병
# 0        1.0  False
# 5        1.0  False
# 7        1.0  False
# 8        1.0  False
# 9        1.0  False
# ...      ...    ...
# 999990   1.0  False
# 999992   1.0  False
# 999993   1.0  False
# 999997   1.0  False
# 999999   1.0  False
#
# [499025 rows x 2 columns]

# %%
df_achol_1['당뇨병'].value_counts()
# Out:
# False    461275
# True      37750
# Name: 당뇨병, dtype: int64

# %%
df_achol_2
# Out:
#         음주여부    당뇨병
# 1        0.0  False
# 2        0.0  False
# 3        0.0  False
# 4        0.0  False
# 6        0.0  False
# ...      ...    ...
# 999991   0.0  False
# 999994   0.0  False
# 999995   0.0  False
# 999996   0.0  False
# 999998   0.0  False
#
# [500975 rows x 2 columns]

# %%
df_achol_2.describe()
# Out:
#            음주여부
# count  500439.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
df_achol_2.value_counts()
# Out:
# 음주여부  당뇨병
# 0.0   False    461011
#       True      39428
# dtype: int64

# %%
df_achol_1.value_counts()
# Out:
# 음주여부  당뇨병
# 1.0   False    461275
#       True      37750
# dtype: int64
